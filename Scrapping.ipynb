# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# !pip install langid
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941171 sha256=3774afcc48c7663c5670cac7933fbfd2cbd96b718c0eb1cf32ad53eaeb13b8ee
#   Stored in directory: /root/.cache/pip/wheels/32/6a/b6/b7eb43a6ad55b139c15c5daa29f3707659cfa6944d3c696f5b
# Successfully built langid
# ...

# %%
# Import library goole_play_scrapper untuk mengakses ulasan dan informasi
from google_play_scraper import app, reviews, Sort
import langid
import pandas as pd

# %%
# Mengambil ulasan dari aplikasi di playstore
scrapreview = reviews_all(
    'com.linecorp.LGGRTHN',
    lang = 'en',
    sort = Sort.MOST_RELEVANT,
)
def english(text):
    if not text:
        return False
    lang, _ = langid.classify(text)
    return lang == 'en'

reviews = [r for r in scrapreview if english(r['content'])]
limited_reviews = reviews[:12000]

# %%
df = pd.DataFrame(reviews)
df.to_csv('getrich_review.csv', index=False)

# %%
import pandas as pd
data = pd.read_csv("/content/getrich_review.csv")

# %%
for review in data["content"]:
    print(review)
# Out:
# Streaming output truncated to the last 5000 lines.
# Nice....
# It made me addicted..
# Very nice
# It's nice
# Awesome!
# LOVE it!
# Love it!
# Perfect!
# Awesome!
# Perfect!
# Love It!
# Love it!
# perfect!
# Awesome!
# Love it!
# Awesome!
# Love it!
# GUE GAK BISA LOGIN LAGI MASAAA?!!! KZL!
# This game 90%sucks...
# Very fun....
# 5 stars
# Very very Good
# Very very good
# like    like     love
# Very very good
# This game is the best game
# Best very best
# Good very good
# Easy To Play
# Funny, even the loading is slow
# Simple. .
# Can't in with line account
# Siiip..!
# I can open this game😝
# It takes forever to load.
# Please Maintance again. Always force close
# I like
# It's awesome
# Love it !!
# Is awsome!!!!!
# top buanget.....
# Good.
# Good
# Loved it
# I love it
# Nice game,,,,
# Just That 😝
# Please be in time
# Really love stage
# I can travel to world
# Remember with the game when i was child
# ZALU YATI SRAPUY
# modoo marble for phone
# I really love this game
# ...
